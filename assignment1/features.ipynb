# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your interests.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for learning_rate in learning_rates:
    for regularization_strength in regularization_strengths:
        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate, regularization_strength,
                  num_iters=3000, verbose=True)
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        validation_accuracy = np.mean(y_val == y_val_pred)
        
        results[(learning_rate, regularization_strength)] = (np.mean(y_train == y_train_pred), validation_accuracy)
        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 3000: loss 81.929328
# iteration 100 / 3000: loss 80.494441
# iteration 200 / 3000: loss 79.091911
# iteration 300 / 3000: loss 77.690898
# iteration 400 / 3000: loss 76.349905
# iteration 500 / 3000: loss 75.002242
# iteration 600 / 3000: loss 73.688911
# iteration 700 / 3000: loss 72.418603
# iteration 800 / 3000: loss 71.170442
# iteration 900 / 3000: loss 69.925107
# iteration 1000 / 3000: loss 68.723393
# iteration 1100 / 3000: loss 67.550524
# iteration 1200 / 3000: loss 66.373168
# iteration 1300 / 3000: loss 65.247553
# iteration 1400 / 3000: loss 64.127794
# iteration 1500 / 3000: loss 63.030703
# iteration 1600 / 3000: loss 61.964615
# iteration 1700 / 3000: loss 60.913551
# iteration 1800 / 3000: loss 59.885169
# iteration 1900 / 3000: loss 58.886108
# iteration 2000 / 3000: loss 57.901398
# iteration 2100 / 3000: loss 56.929347
# iteration 2200 / 3000: loss 55.980442
# iteration 2300 / 3000: loss 55.038472
# iteration 2400 / 3000: loss 54.132953
# iteration 2500 / 3000: loss 53.229484
# iteration 2600 / 3000: loss 52.365628
# iteration 2700 / 3000: loss 51.508008
# iteration 2800 / 3000: loss 50.659442
# iteration 2900 / 3000: loss 49.846245
# iteration 0 / 3000: loss 825.861200
# iteration 100 / 3000: loss 677.726179
# iteration 200 / 3000: loss 556.462288
# iteration 300 / 3000: loss 457.179940
# iteration 400 / 3000: loss 375.900669
# iteration 500 / 3000: loss 309.369494
# iteration 600 / 3000: loss 254.891203
# iteration 700 / 3000: loss 210.296503
# iteration 800 / 3000: loss 173.789601
# iteration 900 / 3000: loss 143.899360
# iteration 1000 / 3000: loss 119.439106
# iteration 1100 / 3000: loss 99.415115
# iteration 1200 / 3000: loss 83.018385
# iteration 1300 / 3000: loss 69.591524
# iteration 1400 / 3000: loss 58.606724
# iteration 1500 / 3000: loss 49.606189
# iteration 1600 / 3000: loss 42.244497
# iteration 1700 / 3000: loss 36.215181
# iteration 1800 / 3000: loss 31.278881
# iteration 1900 / 3000: loss 27.237975
# iteration 2000 / 3000: loss 23.932556
# iteration 2100 / 3000: loss 21.223303
# iteration 2200 / 3000: loss 19.007134
# iteration 2300 / 3000: loss 17.191276
# iteration 2400 / 3000: loss 15.707606
# iteration 2500 / 3000: loss 14.489671
# iteration 2600 / 3000: loss 13.494268
# iteration 2700 / 3000: loss 12.679163
# iteration 2800 / 3000: loss 12.012045
# iteration 2900 / 3000: loss 11.465427
# iteration 0 / 3000: loss 7713.087147
# iteration 100 / 3000: loss 1041.195867
# iteration 200 / 3000: loss 147.293889
# iteration 300 / 3000: loss 27.528180
# iteration 400 / 3000: loss 11.482166
# iteration 500 / 3000: loss 9.332583
# iteration 600 / 3000: loss 9.044560
# iteration 700 / 3000: loss 9.005971
# iteration 800 / 3000: loss 9.000796
# iteration 900 / 3000: loss 9.000103
# iteration 1000 / 3000: loss 9.000010
# iteration 1100 / 3000: loss 8.999998
# iteration 1200 / 3000: loss 8.999996
# iteration 1300 / 3000: loss 8.999997
# iteration 1400 / 3000: loss 8.999996
# iteration 1500 / 3000: loss 8.999997
# iteration 1600 / 3000: loss 8.999996
# iteration 1700 / 3000: loss 8.999996
# iteration 1800 / 3000: loss 8.999996
# iteration 1900 / 3000: loss 8.999995
# iteration 2000 / 3000: loss 8.999996
# iteration 2100 / 3000: loss 8.999996
# iteration 2200 / 3000: loss 8.999996
# iteration 2300 / 3000: loss 8.999997
# iteration 2400 / 3000: loss 8.999996
# iteration 2500 / 3000: loss 8.999997
# iteration 2600 / 3000: loss 8.999997
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999996
# iteration 2900 / 3000: loss 8.999996
# iteration 0 / 3000: loss 84.870293
# iteration 100 / 3000: loss 71.104256
# iteration 200 / 3000: loss 59.844356
# iteration 300 / 3000: loss 50.612374
# iteration 400 / 3000: loss 43.074386
# iteration 500 / 3000: loss 36.890209
# iteration 600 / 3000: loss 31.836848
# iteration 700 / 3000: loss 27.698095
# iteration 800 / 3000: loss 24.309284
# iteration 900 / 3000: loss 21.528248
# iteration 1000 / 3000: loss 19.254034
# iteration 1100 / 3000: loss 17.396240
# iteration 1200 / 3000: loss 15.879002
# iteration 1300 / 3000: loss 14.626409
# iteration 1400 / 3000: loss 13.604636
# iteration 1500 / 3000: loss 12.772491
# iteration 1600 / 3000: loss 12.085211
# iteration 1700 / 3000: loss 11.525993
# iteration 1800 / 3000: loss 11.070758
# iteration 1900 / 3000: loss 10.691809
# iteration 2000 / 3000: loss 10.383930
# iteration 2100 / 3000: loss 10.137100
# iteration 2200 / 3000: loss 9.929419
# iteration 2300 / 3000: loss 9.760573
# iteration 2400 / 3000: loss 9.622623
# iteration 2500 / 3000: loss 9.509082
# iteration 2600 / 3000: loss 9.416937
# iteration 2700 / 3000: loss 9.341179
# iteration 2800 / 3000: loss 9.279328
# iteration 2900 / 3000: loss 9.228457
# iteration 0 / 3000: loss 754.266394
# iteration 100 / 3000: loss 108.849585
# iteration 200 / 3000: loss 22.377640
# iteration 300 / 3000: loss 10.793349
# iteration 400 / 3000: loss 9.240053
# iteration 500 / 3000: loss 9.032206
# iteration 600 / 3000: loss 9.004288
# iteration 700 / 3000: loss 9.000529
# iteration 800 / 3000: loss 9.000038
# iteration 900 / 3000: loss 8.999971
# iteration 1000 / 3000: loss 8.999962
# iteration 1100 / 3000: loss 8.999965
# iteration 1200 / 3000: loss 8.999960
# iteration 1300 / 3000: loss 8.999958
# iteration 1400 / 3000: loss 8.999972
# iteration 1500 / 3000: loss 8.999965
# iteration 1600 / 3000: loss 8.999966
# iteration 1700 / 3000: loss 8.999953
# iteration 1800 / 3000: loss 8.999965
# iteration 1900 / 3000: loss 8.999962
# iteration 2000 / 3000: loss 8.999968
# iteration 2100 / 3000: loss 8.999972
# iteration 2200 / 3000: loss 8.999955
# iteration 2300 / 3000: loss 8.999963
# iteration 2400 / 3000: loss 8.999974
# iteration 2500 / 3000: loss 8.999967
# iteration 2600 / 3000: loss 8.999953
# iteration 2700 / 3000: loss 8.999965
# iteration 2800 / 3000: loss 8.999963
# iteration 2900 / 3000: loss 8.999967
# iteration 0 / 3000: loss 7838.059412
# iteration 100 / 3000: loss 9.000002
# iteration 200 / 3000: loss 8.999996
# iteration 300 / 3000: loss 8.999997
# iteration 400 / 3000: loss 8.999996
# iteration 500 / 3000: loss 8.999996
# iteration 600 / 3000: loss 8.999995
# iteration 700 / 3000: loss 8.999997
# iteration 800 / 3000: loss 8.999997
# iteration 900 / 3000: loss 8.999996
# iteration 1000 / 3000: loss 8.999997
# iteration 1100 / 3000: loss 8.999998
# iteration 1200 / 3000: loss 8.999995
# iteration 1300 / 3000: loss 8.999997
# iteration 1400 / 3000: loss 8.999997
# iteration 1500 / 3000: loss 8.999997
# iteration 1600 / 3000: loss 8.999997
# iteration 1700 / 3000: loss 8.999997
# iteration 1800 / 3000: loss 8.999997
# iteration 1900 / 3000: loss 8.999997
# iteration 2000 / 3000: loss 8.999996
# iteration 2100 / 3000: loss 8.999996
# iteration 2200 / 3000: loss 8.999997
# iteration 2300 / 3000: loss 8.999997
# iteration 2400 / 3000: loss 8.999997
# iteration 2500 / 3000: loss 8.999996
# iteration 2600 / 3000: loss 8.999997
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999996
# iteration 2900 / 3000: loss 8.999996
# iteration 0 / 3000: loss 86.590866
# iteration 100 / 3000: loss 19.391273
# iteration 200 / 3000: loss 10.391203
# iteration 300 / 3000: loss 9.186256
# iteration 400 / 3000: loss 9.024572
# iteration 500 / 3000: loss 9.003001
# iteration 600 / 3000: loss 8.999989
# iteration 700 / 3000: loss 8.999699
# iteration 800 / 3000: loss 8.999695
# iteration 900 / 3000: loss 8.999696
# iteration 1000 / 3000: loss 8.999599
# iteration 1100 / 3000: loss 8.999631
# iteration 1200 / 3000: loss 8.999634
# iteration 1300 / 3000: loss 8.999626
# iteration 1400 / 3000: loss 8.999584
# iteration 1500 / 3000: loss 8.999623
# iteration 1600 / 3000: loss 8.999698
# iteration 1700 / 3000: loss 8.999668
# iteration 1800 / 3000: loss 8.999699
# iteration 1900 / 3000: loss 8.999596
# iteration 2000 / 3000: loss 8.999715
# iteration 2100 / 3000: loss 8.999635
# iteration 2200 / 3000: loss 8.999560
# iteration 2300 / 3000: loss 8.999782
# iteration 2400 / 3000: loss 8.999579
# iteration 2500 / 3000: loss 8.999658
# iteration 2600 / 3000: loss 8.999622
# iteration 2700 / 3000: loss 8.999651
# iteration 2800 / 3000: loss 8.999735
# iteration 2900 / 3000: loss 8.999678
# iteration 0 / 3000: loss 798.515884
# iteration 100 / 3000: loss 8.999968
# iteration 200 / 3000: loss 8.999966
# iteration 300 / 3000: loss 8.999955
# iteration 400 / 3000: loss 8.999968
# iteration 500 / 3000: loss 8.999960
# iteration 600 / 3000: loss 8.999967
# iteration 700 / 3000: loss 8.999963
# iteration 800 / 3000: loss 8.999970
# iteration 900 / 3000: loss 8.999966
# iteration 1000 / 3000: loss 8.999969
# iteration 1100 / 3000: loss 8.999964
# iteration 1200 / 3000: loss 8.999967
# iteration 1300 / 3000: loss 8.999959
# iteration 1400 / 3000: loss 8.999970
# iteration 1500 / 3000: loss 8.999961
# iteration 1600 / 3000: loss 8.999966
# iteration 1700 / 3000: loss 8.999974
# iteration 1800 / 3000: loss 8.999963
# iteration 1900 / 3000: loss 8.999968
# iteration 2000 / 3000: loss 8.999966
# iteration 2100 / 3000: loss 8.999958
# iteration 2200 / 3000: loss 8.999965
# iteration 2300 / 3000: loss 8.999960
# iteration 2400 / 3000: loss 8.999966
# iteration 2500 / 3000: loss 8.999962
# iteration 2600 / 3000: loss 8.999966
# iteration 2700 / 3000: loss 8.999966
# iteration 2800 / 3000: loss 8.999967
# iteration 2900 / 3000: loss 8.999971
# iteration 0 / 3000: loss 7628.679363
# iteration 100 / 3000: loss 9.000000
# iteration 200 / 3000: loss 9.000001
# iteration 300 / 3000: loss 9.000000
# iteration 400 / 3000: loss 9.000000
# iteration 500 / 3000: loss 9.000000
# iteration 600 / 3000: loss 9.000000
# iteration 700 / 3000: loss 9.000000
# iteration 800 / 3000: loss 9.000000
# iteration 900 / 3000: loss 9.000000
# iteration 1000 / 3000: loss 9.000000
# iteration 1100 / 3000: loss 9.000000
# iteration 1200 / 3000: loss 9.000000
# iteration 1300 / 3000: loss 9.000000
# iteration 1400 / 3000: loss 8.999999
# iteration 1500 / 3000: loss 9.000000
# iteration 1600 / 3000: loss 9.000000
# iteration 1700 / 3000: loss 9.000000
# iteration 1800 / 3000: loss 9.000001
# iteration 1900 / 3000: loss 9.000000
# iteration 2000 / 3000: loss 9.000000
# iteration 2100 / 3000: loss 9.000000
# iteration 2200 / 3000: loss 9.000000
# iteration 2300 / 3000: loss 9.000000
# iteration 2400 / 3000: loss 9.000000
# iteration 2500 / 3000: loss 9.000000
# iteration 2600 / 3000: loss 9.000000
# iteration 2700 / 3000: loss 8.999999
# iteration 2800 / 3000: loss 9.000000
# iteration 2900 / 3000: loss 9.000000
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.095163 val accuracy: 0.102000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.105694 val accuracy: 0.101000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.413469 val accuracy: 0.413000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.109061 val accuracy: 0.106000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.412837 val accuracy: 0.412000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.405388 val accuracy: 0.391000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.413959 val accuracy: 0.412000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.408959 val accuracy: 0.411000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.326878 val accuracy: 0.321000
# best validation accuracy achieved during cross-validation: 0.413000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.417

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
results = {}
best_val = -1
best_lr = 0
best_reg = 0

lrs = [1e-2 ,1e-1, 5e-1, 1, 5]
regs = [1e-3, 5e-3, 1e-2, 1e-1, 0.5, 1]

for lr in lrs:
    for reg in regs:
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)

        # Train the network
        stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                    num_iters=1000, batch_size=200,
                    learning_rate=lr, learning_rate_decay=0.95,
                    reg=reg, verbose=True)

        # Predict on the validation set
        val_acc = (net.predict(X_val_feats) == y_val).mean()
        if val_acc > best_val:
            best_net = net
            best_val = val_acc
            best_lr = lr
            best_reg = reg
            
print("best model is:")
print("lr:%f, reg:%f, val accuracy:%f"%(best_lr, best_reg, best_val))
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302523
# iteration 200 / 1000: loss 2.302688
# iteration 300 / 1000: loss 2.302465
# iteration 400 / 1000: loss 2.302130
# iteration 500 / 1000: loss 2.302804
# iteration 600 / 1000: loss 2.302729
# iteration 700 / 1000: loss 2.302531
# iteration 800 / 1000: loss 2.302184
# iteration 900 / 1000: loss 2.302159
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 2.302673
# iteration 200 / 1000: loss 2.302519
# iteration 300 / 1000: loss 2.302622
# iteration 400 / 1000: loss 2.302343
# iteration 500 / 1000: loss 2.302445
# iteration 600 / 1000: loss 2.302427
# iteration 700 / 1000: loss 2.302699
# iteration 800 / 1000: loss 2.301987
# iteration 900 / 1000: loss 2.302673
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 2.302824
# iteration 200 / 1000: loss 2.302611
# iteration 300 / 1000: loss 2.302440
# iteration 400 / 1000: loss 2.302424
# iteration 500 / 1000: loss 2.302856
# iteration 600 / 1000: loss 2.302155
# iteration 700 / 1000: loss 2.302386
# iteration 800 / 1000: loss 2.302526
# iteration 900 / 1000: loss 2.302979
# iteration 0 / 1000: loss 2.302668
# iteration 100 / 1000: loss 2.302817
# iteration 200 / 1000: loss 2.302596
# iteration 300 / 1000: loss 2.302687
# iteration 400 / 1000: loss 2.302645
# iteration 500 / 1000: loss 2.302476
# iteration 600 / 1000: loss 2.302711
# iteration 700 / 1000: loss 2.302313
# iteration 800 / 1000: loss 2.302620
# iteration 900 / 1000: loss 2.302586
# iteration 0 / 1000: loss 2.302995
# iteration 100 / 1000: loss 2.302718
# iteration 200 / 1000: loss 2.302486
# iteration 300 / 1000: loss 2.302463
# iteration 400 / 1000: loss 2.302896
# iteration 500 / 1000: loss 2.302626
# iteration 600 / 1000: loss 2.302668
# iteration 700 / 1000: loss 2.302319
# iteration 800 / 1000: loss 2.302406
# iteration 900 / 1000: loss 2.302259
# iteration 0 / 1000: loss 2.303407
# iteration 100 / 1000: loss 2.302915
# iteration 200 / 1000: loss 2.302634
# iteration 300 / 1000: loss 2.302573
# iteration 400 / 1000: loss 2.302433
# iteration 500 / 1000: loss 2.302457
# iteration 600 / 1000: loss 2.302628
# iteration 700 / 1000: loss 2.302748
# iteration 800 / 1000: loss 2.302546
# iteration 900 / 1000: loss 2.302406
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.301624
# iteration 200 / 1000: loss 2.174252
# iteration 300 / 1000: loss 1.816596
# iteration 400 / 1000: loss 1.610915
# iteration 500 / 1000: loss 1.487554
# iteration 600 / 1000: loss 1.467103
# iteration 700 / 1000: loss 1.394924
# iteration 800 / 1000: loss 1.429011
# iteration 900 / 1000: loss 1.459052
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 2.301686
# iteration 200 / 1000: loss 2.177931
# iteration 300 / 1000: loss 1.934587
# iteration 400 / 1000: loss 1.756141
# iteration 500 / 1000: loss 1.678063
# iteration 600 / 1000: loss 1.554154
# iteration 700 / 1000: loss 1.538660
# iteration 800 / 1000: loss 1.427698
# iteration 900 / 1000: loss 1.470066
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 2.301564
# iteration 200 / 1000: loss 2.165466
# iteration 300 / 1000: loss 2.010508
# iteration 400 / 1000: loss 1.844056
# iteration 500 / 1000: loss 1.660000
# iteration 600 / 1000: loss 1.579717
# iteration 700 / 1000: loss 1.643551
# iteration 800 / 1000: loss 1.579688
# iteration 900 / 1000: loss 1.602386
# iteration 0 / 1000: loss 2.302667
# iteration 100 / 1000: loss 2.303289
# iteration 200 / 1000: loss 2.300208
# iteration 300 / 1000: loss 2.298176
# iteration 400 / 1000: loss 2.265036
# iteration 500 / 1000: loss 2.224104
# iteration 600 / 1000: loss 2.227501
# iteration 700 / 1000: loss 2.194894
# iteration 800 / 1000: loss 2.166719
# iteration 900 / 1000: loss 2.186074
# iteration 0 / 1000: loss 2.302993
# iteration 100 / 1000: loss 2.303817
# iteration 200 / 1000: loss 2.302399
# iteration 300 / 1000: loss 2.301440
# iteration 400 / 1000: loss 2.303748
# iteration 500 / 1000: loss 2.301331
# iteration 600 / 1000: loss 2.302937
# iteration 700 / 1000: loss 2.302886
# iteration 800 / 1000: loss 2.302768
# iteration 900 / 1000: loss 2.302447
# iteration 0 / 1000: loss 2.303403
# iteration 100 / 1000: loss 2.302219
# iteration 200 / 1000: loss 2.303575
# iteration 300 / 1000: loss 2.302996
# iteration 400 / 1000: loss 2.301011
# iteration 500 / 1000: loss 2.302278
# iteration 600 / 1000: loss 2.301377
# iteration 700 / 1000: loss 2.304067
# iteration 800 / 1000: loss 2.302702
# iteration 900 / 1000: loss 2.303548
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 1.477139
# iteration 200 / 1000: loss 1.441279
# iteration 300 / 1000: loss 1.361164
# iteration 400 / 1000: loss 1.297401
# iteration 500 / 1000: loss 1.314181
# iteration 600 / 1000: loss 1.127315
# iteration 700 / 1000: loss 1.173356
# iteration 800 / 1000: loss 1.291546
# iteration 900 / 1000: loss 1.260306
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 1.748070
# iteration 200 / 1000: loss 1.525126
# iteration 300 / 1000: loss 1.651302
# iteration 400 / 1000: loss 1.456930
# iteration 500 / 1000: loss 1.470619
# iteration 600 / 1000: loss 1.446212
# iteration 700 / 1000: loss 1.362424
# iteration 800 / 1000: loss 1.346314
# iteration 900 / 1000: loss 1.429351
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 1.781193
# iteration 200 / 1000: loss 1.654065
# iteration 300 / 1000: loss 1.583306
# iteration 400 / 1000: loss 1.649099
# iteration 500 / 1000: loss 1.601044
# iteration 600 / 1000: loss 1.663659
# iteration 700 / 1000: loss 1.547408
# iteration 800 / 1000: loss 1.713326
# iteration 900 / 1000: loss 1.552736
# iteration 0 / 1000: loss 2.302667
# iteration 100 / 1000: loss 2.200326
# iteration 200 / 1000: loss 2.201063
# iteration 300 / 1000: loss 2.181918
# iteration 400 / 1000: loss 2.130802
# iteration 500 / 1000: loss 2.144677
# iteration 600 / 1000: loss 2.166459
# iteration 700 / 1000: loss 2.122235
# iteration 800 / 1000: loss 2.183314
# iteration 900 / 1000: loss 2.174908
# iteration 0 / 1000: loss 2.302996
# iteration 100 / 1000: loss 2.305281
# iteration 200 / 1000: loss 2.298835
# iteration 300 / 1000: loss 2.303479
# iteration 400 / 1000: loss 2.302873
# iteration 500 / 1000: loss 2.301464
# iteration 600 / 1000: loss 2.302655
# iteration 700 / 1000: loss 2.304509
# iteration 800 / 1000: loss 2.306343
# iteration 900 / 1000: loss 2.305617
# iteration 0 / 1000: loss 2.303405
# iteration 100 / 1000: loss 2.299770
# iteration 200 / 1000: loss 2.303578
# iteration 300 / 1000: loss 2.301762
# iteration 400 / 1000: loss 2.306034
# iteration 500 / 1000: loss 2.300991
# iteration 600 / 1000: loss 2.302756
# iteration 700 / 1000: loss 2.307748
# iteration 800 / 1000: loss 2.301810
# iteration 900 / 1000: loss 2.305920
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 1.574572
# iteration 200 / 1000: loss 1.496360
# iteration 300 / 1000: loss 1.439766
# iteration 400 / 1000: loss 1.407760
# iteration 500 / 1000: loss 1.396131
# iteration 600 / 1000: loss 1.222410
# iteration 700 / 1000: loss 1.431044
# iteration 800 / 1000: loss 1.379501
# iteration 900 / 1000: loss 1.305370
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 1.624870
# iteration 200 / 1000: loss 1.516820
# iteration 300 / 1000: loss 1.582101
# iteration 400 / 1000: loss 1.494609
# iteration 500 / 1000: loss 1.456666
# iteration 600 / 1000: loss 1.626942
# iteration 700 / 1000: loss 1.512544
# iteration 800 / 1000: loss 1.389128
# iteration 900 / 1000: loss 1.497906
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 1.773439
# iteration 200 / 1000: loss 1.687609
# iteration 300 / 1000: loss 1.606237
# iteration 400 / 1000: loss 1.673874
# iteration 500 / 1000: loss 1.711396
# iteration 600 / 1000: loss 1.740790
# iteration 700 / 1000: loss 1.545280
# iteration 800 / 1000: loss 1.686816
# iteration 900 / 1000: loss 1.707100
# iteration 0 / 1000: loss 2.302667
# iteration 100 / 1000: loss 2.202825
# iteration 200 / 1000: loss 2.209054
# iteration 300 / 1000: loss 2.148257
# iteration 400 / 1000: loss 2.187862
# iteration 500 / 1000: loss 2.176961
# iteration 600 / 1000: loss 2.145745
# iteration 700 / 1000: loss 2.162964
# iteration 800 / 1000: loss 2.184109
# iteration 900 / 1000: loss 2.166560
# iteration 0 / 1000: loss 2.302994
# iteration 100 / 1000: loss 2.298152
# iteration 200 / 1000: loss 2.301122
# iteration 300 / 1000: loss 2.304721
# iteration 400 / 1000: loss 2.305664
# iteration 500 / 1000: loss 2.300221
# iteration 600 / 1000: loss 2.300643
# iteration 700 / 1000: loss 2.304173
# iteration 800 / 1000: loss 2.303732
# iteration 900 / 1000: loss 2.306853
# iteration 0 / 1000: loss 2.303406
# D:\Project\juypterProject\py36\cs231n\assignment1\cs231n\classifiers\neural_net.py:100: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log(score_class[np.arange(N), y]))
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss inf
# iteration 700 / 1000: loss inf
# iteration 800 / 1000: loss inf
# D:\Project\juypterProject\py36\cs231n\assignment1\cs231n\classifiers\neural_net.py:97: RuntimeWarning: overflow encountered in subtract
#   scores_scale = scores - np.max(scores, axis = 1).reshape(-1, 1)
# D:\Project\juypterProject\py36\cs231n\assignment1\cs231n\classifiers\neural_net.py:102: RuntimeWarning: overflow encountered in double_scalars
#   loss += reg * (np.sum(W1 * W1) + np.sum(W2 * W2))
# D:\Project\juypterProject\py36\cs231n\assignment1\cs231n\classifiers\neural_net.py:97: RuntimeWarning: invalid value encountered in subtract
#   scores_scale = scores - np.max(scores, axis = 1).reshape(-1, 1)
# D:\Project\juypterProject\py36\cs231n\assignment1\cs231n\classifiers\neural_net.py:78: RuntimeWarning: invalid value encountered in maximum
#   scores_hidden = np.maximum(X.dot(W1) + b1, 0)
# D:\Project\juypterProject\py36\cs231n\assignment1\cs231n\classifiers\neural_net.py:120: RuntimeWarning: invalid value encountered in less_equal
#   grad_relu[scores_hidden <= 0] = 0
# iteration 900 / 1000: loss nan
# D:\Project\juypterProject\py36\cs231n\assignment1\cs231n\classifiers\neural_net.py:237: RuntimeWarning: invalid value encountered in maximum
#   scores_pred = np.maximum(X.dot(W1) + b1, 0).dot(W2) + b2
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# iteration 0 / 1000: loss 2.302667
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss 11873597558605868142736993487844463806805070854457080097856542363581648137353914303788534815105454294819059612582930996670580066877440.000000
# iteration 400 / 1000: loss 11.742562
# iteration 500 / 1000: loss 2.320781
# iteration 600 / 1000: loss 2.307670
# iteration 700 / 1000: loss 2.299405
# iteration 800 / 1000: loss 2.313687
# iteration 900 / 1000: loss 2.309127
# iteration 0 / 1000: loss 2.302997
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# iteration 0 / 1000: loss 2.303408
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# best model is:
# lr:0.500000, reg:0.001000, val accuracy:0.572000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
